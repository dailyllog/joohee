# %% [markdown]
# !문제 1번!
# -
# a = '형근이는 주희를 좋아해. 형근이는 몽이도 좋아해'
# - '몽이'라는 단어가 있는지 없는지 찾기

# %%
a = '형근이는 주희를 좋아해. 형근이는 몽이도 좋아해'

if "몽이" in a:
    print("찾았다!")
else:
    print("없다!")
# Out:
# 찾았다!

# %%
#몽이가 몇 번째 인덱스에 있는지 찾아보세요.

if "몽이" in len(a):
